# %%
import os
import mlflow
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Загрузка данных Титаника из csv-файла
df = pd.read_csv('titanic.csv')
# data = data [['Survived','Pclass','Age','Fare']]
# data = data.dropna(subset=['Age'])

# %% [markdown]
# ## Предварительная обработка данных

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.iloc[:,-2].unique()
df.iloc[:,-2].value_counts()
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Удаляем столбцы, в которых нет ценной для нас информации
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], 
        axis=1, 
        inplace=True)

# %%
df.head(3)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.Fare.isna().sum(), df.Embarked.isna().sum(), df.shape
# Out:
# (np.int64(0), np.int64(2), (891, 8))

# %%
df = df.dropna(subset=['Age'])
df = df.dropna(subset=['Embarked'])
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 885         0       3  female  39.0      0      5  29.1250        Q
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [712 rows x 8 columns]

# %%
# Округляем стоимость билета до двух знаков после запятой
df['Fare'] = round(df['Fare']).astype(int)
df['Age'] = df['Age'].astype(int)
df.head(5)
# Out:
#    Survived  Pclass     Sex  Age  SibSp  Parch  Fare Embarked
# 0         0       3    male   22      1      0     7        S
# 1         1       1  female   38      1      0    71        C
# 2         1       3  female   26      0      0     8        S
# 3         1       1  female   35      1      0    53        S
# 4         0       3    male   35      0      0     8        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    int64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    int64
#  7   Embarked  712 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 50.1+ KB

# %% [markdown]
# Осталось поменять типы данных в столбцах Sex и Embarked

# %%
df.Sex.unique(), df.Embarked.unique()
# Out:
# (array(['male', 'female'], dtype=object), array(['S', 'C', 'Q'], dtype=object))

# %%
df['Sex'] =  np.where(df['Sex']=="female", 0, 1)
df['Embarked'] =  np.where(df['Embarked']=="S", 0, np.where(df['Embarked']=="C", 1, 2))
                # np.where(df[1]=="B", "1",
                #         np.where(df[1]=="C","2",
                #                 np.where(df[1]=="D","3",np.nan))))
print(df)
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0           0       3    1   22      1      0     7         0
# 1           1       1    0   38      1      0    71         1
# 2           1       3    0   26      0      0     8         0
# 3           1       1    0   35      1      0    53         0
# 4           0       3    1   35      0      0     8         0
# ..        ...     ...  ...  ...    ...    ...   ...       ...
# 885         0       3    0   39      0      5    29         2
# 886         0       2    1   27      0      0    13         0
# 887         1       1    0   19      0      0    30         0
# 889         1       1    1   26      0      0    30         1
# 890         0       3    1   32      0      0     8         2
#
# [712 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    int64
#  3   Age       712 non-null    int64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    int64
#  7   Embarked  712 non-null    int64
# dtypes: int64(8)
# memory usage: 50.1 KB

# %%
df.to_csv('titanic_clear.csv', sep=',', encoding='utf-8', index=False)

# %%
pd.read_csv('titanic_clear.csv')
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0           0       3    1   22      1      0     7         0
# 1           1       1    0   38      1      0    71         1
# 2           1       3    0   26      0      0     8         0
# 3           1       1    0   35      1      0    53         0
# 4           0       3    1   35      0      0     8         0
# ..        ...     ...  ...  ...    ...    ...   ...       ...
# 707         0       3    0   39      0      5    29         2
# 708         0       2    1   27      0      0    13         0
# 709         1       1    0   19      0      0    30         0
# 710         1       1    1   26      0      0    30         1
# 711         0       3    1   32      0      0     8         2
#
# [712 rows x 8 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_312c2_row0_col0, #T_312c2_row1_col1, #T_312c2_row2_col2, #T_312c2_row3_col3, #T_312c2_row4_col4, #T_312c2_row5_col5, #T_312c2_row6_col6, #T_312c2_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_312c2_row0_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_312c2_row0_col2, #T_312c2_row1_col3, #T_312c2_row1_col6, #T_312c2_row1_col7, #T_312c2_row2_col0, #T_312c2_row2_col5, #T_312c2_row3_col4, #T_312c2_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_312c2_row0_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_312c2_row0_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_312c2_row0_col5, #T_312c2_row7_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_312c2_row0_col6 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_312c2_row0_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_312c2_row1_col0, #T_312c2_row3_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_312c2_row1_col2, #T_312c2_row4_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_312c2_row1_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_312c2_row1_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_312c2_row2_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_312c2_row2_col3, #T_312c2_row6_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_312c2_row2_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_312c2_row2_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_312c2_row2_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_312c2_row3_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_312c2_row3_col2, #T_312c2_row5_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_312c2_row3_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_312c2_row3_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_312c2_row3_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_312c2_row4_col0, #T_312c2_row6_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_312c2_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_312c2_row4_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_312c2_row4_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_312c2_row4_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_312c2_row4_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_312c2_row5_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_312c2_row5_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_312c2_row5_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_312c2_row5_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_312c2_row5_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_312c2_row5_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_312c2_row6_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_312c2_row6_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_312c2_row6_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_312c2_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_312c2_row7_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_312c2_row7_col1, #T_312c2_row7_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_312c2_row7_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_312c2_row7_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_312c2_row7_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_312c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_312c2_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_312c2_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_312c2_level0_col2" class="col_heading level0 col2" >Sex</th>
#       <th id="T_312c2_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_312c2_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_312c2_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_312c2_level0_col6" class="col_heading level0 col6" >Fare</th>
#       <th id="T_312c2_level0_col7" class="col_heading level0 col7" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_312c2_level0_row0" class="row_heading level0 row0" >Survived</th>
#       <td id="T_312c2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_312c2_row0_col1" class="data row0 col1" >-0.356462</td>
#       <td id="T_312c2_row0_col2" class="data row0 col2" >-0.536762</td>
#       <td id="T_312c2_row0_col3" class="data row0 col3" >-0.082377</td>
#       <td id="T_312c2_row0_col4" class="data row0 col4" >-0.015523</td>
#       <td id="T_312c2_row0_col5" class="data row0 col5" >0.095265</td>
#       <td id="T_312c2_row0_col6" class="data row0 col6" >0.265888</td>
#       <td id="T_312c2_row0_col7" class="data row0 col7" >0.108517</td>
#     </tr>
#     <tr>
#       <th id="T_312c2_level0_row1" class="row_heading level0 row1" >Pclass</th>
#       <td id="T_312c2_row1_col0" class="data row1 col0" >-0.356462</td>
#       <td id="T_312c2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_312c2_row1_col2" class="data row1 col2" >0.150826</td>
#       <td id="T_312c2_row1_col3" class="data row1 col3" >-0.366125</td>
#       <td id="T_312c2_row1_col4" class="data row1 col4" >0.065187</td>
#       <td id="T_312c2_row1_col5" class="data row1 col5" >0.023666</td>
#       <td id="T_312c2_row1_col6" class="data row1 col6" >-0.553044</td>
#       <td id="T_312c2_row1_col7" class="data row1 col7" >-0.108502</td>
#     </tr>
#     <tr>
#       <th id="T_312c2_level0_row2" class="row_heading level0 row2" >Sex</th>
#       <td id="T_312c2_row2_col0" class="data row2 col0" >-0.536762</td>
#       <td id="T_312c2_row2_col1" class="data row2 col1" >0.150826</td>
#       <td id="T_312c2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_312c2_row2_col3" class="data row2 col3" >0.098535</td>
#       <td id="T_312c2_row2_col4" class="data row2 col4" >-0.106296</td>
#       <td id="T_312c2_row2_col5" class="data row2 col5" >-0.249543</td>
#       <td id="T_312c2_row2_col6" class="data row2 col6" >-0.182040</td>
#       <td id="T_312c2_row2_col7" class="data row2 col7" >-0.097129</td>
#     </tr>
#     <tr>
#       <th id="T_312c2_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_312c2_row3_col0" class="data row3 col0" >-0.082377</td>
#       <td id="T_312c2_row3_col1" class="data row3 col1" >-0.366125</td>
#       <td id="T_312c2_row3_col2" class="data row3 col2" >0.098535</td>
#       <td id="T_312c2_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_312c2_row3_col4" class="data row3 col4" >-0.307050</td>
#       <td id="T_312c2_row3_col5" class="data row3 col5" >-0.188084</td>
#       <td id="T_312c2_row3_col6" class="data row3 col6" >0.093519</td>
#       <td id="T_312c2_row3_col7" class="data row3 col7" >0.011393</td>
#     </tr>
#     <tr>
#       <th id="T_312c2_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_312c2_row4_col0" class="data row4 col0" >-0.015523</td>
#       <td id="T_312c2_row4_col1" class="data row4 col1" >0.065187</td>
#       <td id="T_312c2_row4_col2" class="data row4 col2" >-0.106296</td>
#       <td id="T_312c2_row4_col3" class="data row4 col3" >-0.307050</td>
#       <td id="T_312c2_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_312c2_row4_col5" class="data row4 col5" >0.383338</td>
#       <td id="T_312c2_row4_col6" class="data row4 col6" >0.139785</td>
#       <td id="T_312c2_row4_col7" class="data row4 col7" >0.004021</td>
#     </tr>
#     <tr>
#       <th id="T_312c2_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_312c2_row5_col0" class="data row5 col0" >0.095265</td>
#       <td id="T_312c2_row5_col1" class="data row5 col1" >0.023666</td>
#       <td id="T_312c2_row5_col2" class="data row5 col2" >-0.249543</td>
#       <td id="T_312c2_row5_col3" class="data row5 col3" >-0.188084</td>
#       <td id="T_312c2_row5_col4" class="data row5 col4" >0.38333

# %% [markdown]
# Короче тут выжившие больше всего коррелируются с классом, полом и стоимостью билета

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    int64
#  3   Age       712 non-null    int64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    int64
#  7   Embarked  712 non-null    int64
# dtypes: int64(8)
# memory usage: 50.1 KB

# %% [markdown]
# Survived — факт выживания (1 = выжил, 0 = погиб).
# Pclass — класс билета/социально-экономический статус (1 = высший, 2 = средний, 3 = низший).
# Sex — пол пассажира.
# Age — возраст пассажира (часть значений отсутствует).
# SibSp — число родных братьев/сестёр или супругов на борту.
# Parch — число родителей/детей на борту.
# Fare — стоимость проезда.
# Embarked — порт посадки (С = Шербург, Q = Куинстаун, S = Саутгемптон).

# %% [markdown]
# Все данные готовы и переданы в файл titanic_clear.csv
